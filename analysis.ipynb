# %%
import pandas as pd

# %%
data = pd.read_excel("rekap_data_terorisme_loc_v4.xlsx")

# %%
data.head()
# Out:
#                             File_Name                          case_id  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json    02/Pid. Sus./2014/PN. Jkt. Ut
# 1   1005_PID~SUS_2020_PN JKT~BRT.json  1005/Pid. Sus/2020/PN. Jkt. Brt
# 2   1006_PID~SUS_2020_PN JKT~BRT.json  1006/Pid. Sus/2020/PN. Jkt. Brt
# 3   1012_PID~SUS_2021_PN JKT~TIM.json  1012 Pid. SUS/2021/PN. Jkt. Tim
# 4   1014_PID~SUS_2021_PN JKT~TIM.json   1014/Pid. Sus/2021/PN Jkt. Tim
#
#                   what_case_number                        what_court_name  \
# 0    02/Pid. Sus./2014/PN. Jkt. Ut        Pengadilan Negeri Jakarta Utara
# 1  1005/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 2  1006/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 3  1012 Pid. SUS/2021/PN. Jkt. Tim  Pengadilan Negeri Jakarta Timur sejak
# 4   1014/Pid. Sus/2021/PN Jkt. Tim        Pengadilan Negeri Jakarta Timur
#
#   what_court_level                              what_charged_articles  \
# 0          pertama  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1          pertama  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2          pertama  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#   what_indictment_model                                what_proven_offense  \
# 0            Alternatif  permufakataan jahat dengan sengaja melakukan k...
# 1            Alternatif                            Tindak Pidana Terorisme
# 2            Alternatif                            Tindak Pidana Terorisme
# 3                   NaN                            Tindak Pidana Terorisme
# 4             Kombinasi    tindak pidana Terorisme dan Pendanaan Terorisme
#
#   what_verdict_per_charge what_appellate_outcome  ...  \
# 0                Terbukti                    NaN  ...
# 1                Terbukti                    NaN  ...
# 2                Terbukti                    NaN  ...
# 3                Terbukti                    NaN  ...
# 4       Primair: Terbukti                    NaN  ...
#
#                               why_mitigating_factors  \
# 0                                                NaN
# 1  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
# 2  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
# 3  Terdakwa bersikap sopan dipersidangan\n---\nTe...
# 4  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
#
#                           why_radicalization_sources  \
# 0                                                NaN
# 1  kajian ustadz MUHLIS\n---\nFacebook\n---\ntele...
# 2  grup Media Sosial Whats App MENITI TAUHID\n---...
# 3  kajian Diniyah di Mushola daerah Ds. Pondok Su...
# 4                                                NaN
#
#                               why_motivation_factors  how_much_prison_term  \
# 0                                                NaN                   NaN
# 1                                                NaN  Years: 3 | Months: 6
# 2                                                NaN  Years: 3 | Months: 6
# 3  keinginan untuk hidup dibawah naungan Negara S...  Years: 3 | Months: 6
# 4                                                NaN  Years: 4 | Months: 6
#
#   how_much_injury_severity what_detention_credit  \
# 0                      NaN                   NaN
# 1         Tidak ada korban                   NaN
# 2         Tidak ada korban                  True
# 3         Tidak ada korban                   NaN
# 4         Tidak ada korban                  True
#
#        where_detention_location how_much_monetary_penalties  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3  Rumah Tahanan Negara (RUTAN)                         NaN
# 4                           NaN                  50.000.000
#
#   how_much_seized_money_amount when_indictment_date
# 0                          NaN                  NaN
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
# [5 rows x 59 columns]

# %%
data.columns
# Out:
# Index(['File_Name', 'case_id', 'what_case_number', 'what_court_name',
#        'what_court_level', 'what_charged_articles', 'what_indictment_model',
#        'what_proven_offense', 'what_verdict_per_charge',
#        'what_appellate_outcome', 'what_evidence_items',
#        'what_evidence_disposition', 'what_defense_plea',
#        'what_pelatihan_activities', 'what_perencanaan_activities',
#        'what_tindakan_activities', 'when_appeal_timeline', 'when_arrest_date',
#        'when_crime_time_range', 'when_detention_timeline',
#        'where_district_court', 'who_defendants', 'who_co_defendants',
#        'who_defense_counsels', 'who_investigators', 'who_judges', 'who_clerk',
#        'who_prosecutors', 'who_witnesses', 'why_reasoning_evidence',
#        'why_reasoning_appeal', 'how_many_witness_count',
#        'how_many_charge_count', 'how_many_defendant_count',
#        'how_many_evidence_item_count', 'what_has_attack_plan',
#        'what_attack_preparation_activities', 'what_attack_plan_summary',
#        'what_defendant_chat_platform', 'when_district_court_date',
#        'when_defendant_local_network_joined_at', 'where_court_location',
#        'where_activity_locations', 'where_crime_location',
#        'where_arrest_location', 'who_defendant_ideology_affiliation',
#        'who_defendant_local_network', 'who_related_entities',
#        'why_aggravating_factors', 'why_mitigating_factors',
#        'why_radicalization_sources', 'why_motivation_factors',
#        'how_much_prison_term', 'how_much_injury_severity',
#        'what_detention_credit', 'where_detention_location',
#        'how_much_monetary_penalties', 'how_much_seized_money_amount',
#        'when_indictment_date'],
#       dtype='str')

# %%
data.loc[
    data["who_defendant_ideology_affiliation"].isna() |
    (
        data["who_defendant_ideology_affiliation"]
        .str.lower()
        .str.strip() == "tidak diketahui"
    ),
    "who_defendant_local_network"
] = None

# %%
data.to_excel("rekap_data_terorisme_loc_v4.xlsx", index=False)

# %%
len(data.columns)
# Out:
# 59

# %%
df_filtered = data[["who_defendant_ideology_affiliation", "File_Name", "what_charged_articles", "who_defendant_local_network"]]
df_filtered.head()
# Out:
#   who_defendant_ideology_affiliation                           File_Name  \
# 0                                NaN  02_PID~ SUS~_2014_PN~JKT~ UT~.json
# 1              Daulah Islamiyah/ISIS   1005_PID~SUS_2020_PN JKT~BRT.json
# 2                      Kelompok ISIS   1006_PID~SUS_2020_PN JKT~BRT.json
# 3              Jamaah Islamiyah (JI)   1012_PID~SUS_2021_PN JKT~TIM.json
# 4              Jamaah Islamiyah (JI)   1014_PID~SUS_2021_PN JKT~TIM.json
#
#                                what_charged_articles  \
# 0  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#              who_defendant_local_network
# 0                                    NaN
# 1  Klinik Rukiah Kota Padang (Halaman 4)
# 2          Kediri Jawa Timur (Halaman 5)
# 3                     Klaten (Halaman 4)
# 4                Jawa Tengah (Halaman 5)

# %%
unknown_ideology = df_filtered[
    (df_filtered["who_defendant_ideology_affiliation"] == "Tidak Diketahui") |
    (df_filtered["who_defendant_ideology_affiliation"].isna())
]

print(len(unknown_ideology))
# Out:
# 99

# %%
unknown_ideology.tail(13)
# Out:
#     who_defendant_ideology_affiliation                         File_Name  \
# 441                                NaN         79K_PM~I04_AD_X_2020.json
# 442                                NaN       79_PID~SUS_2015_PN MLN.json
# 443                                NaN         7_PID~SUS_2011_PT~PR.json
# 448                    Tidak Diketahui           807 K_PID~SUS_2011.json
# 449                    Tidak Diketahui           80_PID_2012_PT~BTN.json
# 462                                NaN      84_PID~SUS_2015_PN~TBK~.json
# 463                                NaN       85_PID~SUS_2021_PN KLB.json
# 467                    Tidak Diketahui  878_PID~SUS_2021_PN JKT~TIM.json
# 468                    Tidak Diketahui           893 K_PID~SUS_2009.json
# 469                    Tidak Diketahui          8_PID~B_2022_PN SBH.json
# 470                    Tidak Diketahui           904 K_PID~SUS_2009.json
# 475                                NaN      939_PID~SUS_2012_PN~DPS.json
# 500                                NaN       99_PID_SUS_2016_PN_SDN.json
#
#                                  what_charged_articles  \
# 441  Pasal 1 ayat (1) UU RI Darurat No. 12 tahun 19...
# 442  Pasal 112 ayat (1) UU Nomor 35 Tahun 2009 tent...
# 443  Pasal 114 ayat 1 UU Nomor 35 Tahun 2009 tentan...
# 448                              Pasal 15 UU Terorisme
# 449  Pasal 14 jo. Pasal 7 UU No. 15 Tahun 2003 Tent...
# 462  Pasal 112 Ayat (1) UU Nomor 35 tahun 2009 tent...
# 463                                                NaN
# 467                       Pasal 363 Ayat (1) ke-4 KUHP
# 468  Pasal 6 UU No. 15 Tahun 2003\n---\nPasal 55 ay...
# 469              Pasal 335 ayat (1) angka 1 KUHP idana
# 470  Pasal 6 Undang-Undang RI Nomor.15 Tahun 2003 t...
# 475  Pasal 114 ayat (1) UU RI No.35 Tahun 2009 tent...
# 500  Pasal 112 ayat (1) UU RI No. 35 Tahun 2009 Ten...
#
#      who_defendant_local_network
# 441                    Palembang
# 442                          NaN
# 443                          NaN
# 448                          NaN
# 449            Bima (Halaman 15)
# 462                          NaN
# 463                          NaN
# 467                          NaN
# 468  Polewali Mandar (Halaman 1)
# 469                          NaN
# 470   Sulawesi Barat (Halaman 1)
# 475                          NaN
# 500                          NaN

# %%
df_filtered.loc[
    df_filtered["who_defendant_ideology_affiliation"].isna() |
    (
        df_filtered["who_defendant_ideology_affiliation"]
        .str.lower()
        .str.strip() == "tidak diketahui"
    ),
    "who_defendant_local_network"
] = None

# %%
df_filtered.head()
# Out:
#   who_defendant_ideology_affiliation                           File_Name  \
# 0                                NaN  02_PID~ SUS~_2014_PN~JKT~ UT~.json
# 1              Daulah Islamiyah/ISIS   1005_PID~SUS_2020_PN JKT~BRT.json
# 2                      Kelompok ISIS   1006_PID~SUS_2020_PN JKT~BRT.json
# 3              Jamaah Islamiyah (JI)   1012_PID~SUS_2021_PN JKT~TIM.json
# 4              Jamaah Islamiyah (JI)   1014_PID~SUS_2021_PN JKT~TIM.json
#
#                                what_charged_articles  \
# 0  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#              who_defendant_local_network
# 0                                    NaN
# 1  Klinik Rukiah Kota Padang (Halaman 4)
# 2          Kediri Jawa Timur (Halaman 5)
# 3                     Klaten (Halaman 4)
# 4                Jawa Tengah (Halaman 5)

# %%
unknown_ideology = df_filtered[
    (df_filtered["who_defendant_ideology_affiliation"] == "Tidak Diketahui") |
    (df_filtered["who_defendant_ideology_affiliation"].isna())
]

print(len(unknown_ideology))
# Out:
# 99

# %%
unknown_ideology.to_excel("unknown_ideology4.xlsx", index=False)

# %% [markdown]
# ## Mitigating and Aggravating

# %%
data = pd.read_excel("rekap_data_terorisme_loc_v4.xlsx")
data.head()
# Out:
#                             File_Name                          case_id  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json    02/Pid. Sus./2014/PN. Jkt. Ut
# 1   1005_PID~SUS_2020_PN JKT~BRT.json  1005/Pid. Sus/2020/PN. Jkt. Brt
# 2   1006_PID~SUS_2020_PN JKT~BRT.json  1006/Pid. Sus/2020/PN. Jkt. Brt
# 3   1012_PID~SUS_2021_PN JKT~TIM.json  1012 Pid. SUS/2021/PN. Jkt. Tim
# 4   1014_PID~SUS_2021_PN JKT~TIM.json   1014/Pid. Sus/2021/PN Jkt. Tim
#
#                   what_case_number                        what_court_name  \
# 0    02/Pid. Sus./2014/PN. Jkt. Ut        Pengadilan Negeri Jakarta Utara
# 1  1005/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 2  1006/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 3  1012 Pid. SUS/2021/PN. Jkt. Tim  Pengadilan Negeri Jakarta Timur sejak
# 4   1014/Pid. Sus/2021/PN Jkt. Tim        Pengadilan Negeri Jakarta Timur
#
#   what_court_level                              what_charged_articles  \
# 0          pertama  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1          pertama  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2          pertama  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#   what_indictment_model                                what_proven_offense  \
# 0            Alternatif  permufakataan jahat dengan sengaja melakukan k...
# 1            Alternatif                            Tindak Pidana Terorisme
# 2            Alternatif                            Tindak Pidana Terorisme
# 3                   NaN                            Tindak Pidana Terorisme
# 4             Kombinasi    tindak pidana Terorisme dan Pendanaan Terorisme
#
#   what_verdict_per_charge what_appellate_outcome  ...  \
# 0                Terbukti                    NaN  ...
# 1                Terbukti                    NaN  ...
# 2                Terbukti                    NaN  ...
# 3                Terbukti                    NaN  ...
# 4       Primair: Terbukti                    NaN  ...
#
#                           why_radicalization_sources  \
# 0                                                NaN
# 1  kajian ustadz MUHLIS\n---\nFacebook\n---\ntele...
# 2  grup Media Sosial Whats App MENITI TAUHID\n---...
# 3  kajian Diniyah di Mushola daerah Ds. Pondok Su...
# 4                                                NaN
#
#                               why_motivation_factors  how_much_prison_term  \
# 0                                                NaN                   NaN
# 1                                                NaN  Years: 3 | Months: 6
# 2                                                NaN  Years: 3 | Months: 6
# 3  keinginan untuk hidup dibawah naungan Negara S...  Years: 3 | Months: 6
# 4                                                NaN  Years: 4 | Months: 6
#
#   how_much_injury_severity what_detention_credit  \
# 0                      NaN                   NaN
# 1         Tidak ada korban                   NaN
# 2         Tidak ada korban                   1.0
# 3         Tidak ada korban                   NaN
# 4         Tidak ada korban                   1.0
#
#        where_detention_location how_much_monetary_penalties  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3  Rumah Tahanan Negara (RUTAN)                         NaN
# 4                           NaN                  50.000.000
#
#   how_much_seized_money_amount when_indictment_date  \
# 0                          NaN                  NaN
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#   who_defendant_local_network
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 60 columns]

# %%
df_filtered = data[["why_mitigating_factors", "File_Name"]]
df_filtered.head()
# Out:
#                               why_mitigating_factors  \
# 0                                                NaN
# 1  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
# 2  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
# 3  Terdakwa bersikap sopan dipersidangan\n---\nTe...
# 4  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
#
#                             File_Name
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json
# 1   1005_PID~SUS_2020_PN JKT~BRT.json
# 2   1006_PID~SUS_2020_PN JKT~BRT.json
# 3   1012_PID~SUS_2021_PN JKT~TIM.json
# 4   1014_PID~SUS_2021_PN JKT~TIM.json

# %%
unknown_mitigating = df_filtered[
    (df_filtered["why_mitigating_factors"] == "Tidak Diketahui") |
    (df_filtered["why_mitigating_factors"].isna())
]

print(len(unknown_ideology))
# Out:
# 222

# %%
unknown_mitigating.to_excel("unknown_mitigating.xlsx", index=False)

# %% [markdown]
# ## Unknown Charge Articles

# %%
data = pd.read_excel("rekap_data_terorisme_loc_v6.xlsx")
data.head()
# Out:
#                             File_Name                          case_id  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json    02/Pid. Sus./2014/PN. Jkt. Ut
# 1   1005_PID~SUS_2020_PN JKT~BRT.json  1005/Pid. Sus/2020/PN. Jkt. Brt
# 2   1006_PID~SUS_2020_PN JKT~BRT.json  1006/Pid. Sus/2020/PN. Jkt. Brt
# 3   1012_PID~SUS_2021_PN JKT~TIM.json  1012 Pid. SUS/2021/PN. Jkt. Tim
# 4   1014_PID~SUS_2021_PN JKT~TIM.json   1014/Pid. Sus/2021/PN Jkt. Tim
#
#                   what_case_number                        what_court_name  \
# 0    02/Pid. Sus./2014/PN. Jkt. Ut        Pengadilan Negeri Jakarta Utara
# 1  1005/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 2  1006/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 3  1012 Pid. SUS/2021/PN. Jkt. Tim  Pengadilan Negeri Jakarta Timur sejak
# 4   1014/Pid. Sus/2021/PN Jkt. Tim        Pengadilan Negeri Jakarta Timur
#
#   what_court_level                              what_charged_articles  \
# 0          pertama  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1          pertama  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2          pertama  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#   what_indictment_model                                what_proven_offense  \
# 0            Alternatif  permufakataan jahat dengan sengaja melakukan k...
# 1            Alternatif                            Tindak Pidana Terorisme
# 2            Alternatif                            Tindak Pidana Terorisme
# 3                   NaN                            Tindak Pidana Terorisme
# 4             Kombinasi    tindak pidana Terorisme dan Pendanaan Terorisme
#
#   what_verdict_per_charge what_appellate_outcome  ...  \
# 0                Terbukti                    NaN  ...
# 1                Terbukti                    NaN  ...
# 2                Terbukti                    NaN  ...
# 3                Terbukti                    NaN  ...
# 4       Primair: Terbukti                    NaN  ...
#
#                           why_radicalization_sources  \
# 0                                                NaN
# 1  kajian ustadz MUHLIS\n---\nFacebook\n---\ntele...
# 2  grup Media Sosial Whats App MENITI TAUHID\n---...
# 3  kajian Diniyah di Mushola daerah Ds. Pondok Su...
# 4                                                NaN
#
#                               why_motivation_factors  how_much_prison_term  \
# 0                                                NaN                   NaN
# 1                                                NaN  Years: 3 | Months: 6
# 2                                                NaN  Years: 3 | Months: 6
# 3  keinginan untuk hidup dibawah naungan Negara S...  Years: 3 | Months: 6
# 4                                                NaN  Years: 4 | Months: 6
#
#   how_much_injury_severity what_detention_credit  \
# 0                      NaN                   NaN
# 1         Tidak ada korban                   NaN
# 2         Tidak ada korban                  True
# 3         Tidak ada korban                   NaN
# 4         Tidak ada korban                  True
#
#        where_detention_location how_much_monetary_penalties  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3  Rumah Tahanan Negara (RUTAN)                         NaN
# 4                           NaN                  50.000.000
#
#   what_is_imputed_articles how_much_seized_money_amount when_indictment_date
# 0                      NaN                          NaN                  NaN
# 1                      NaN                          NaN                  NaN
# 2                      NaN                          NaN                  NaN
# 3                      NaN                          NaN                  NaN
# 4                      NaN                          NaN                  NaN
#
# [5 rows x 60 columns]

# %%
df_filtered = data[["File_Name", "what_charged_articles"]]
df_filtered.head()
# Out:
#                             File_Name  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json
# 1   1005_PID~SUS_2020_PN JKT~BRT.json
# 2   1006_PID~SUS_2020_PN JKT~BRT.json
# 3   1012_PID~SUS_2021_PN JKT~TIM.json
# 4   1014_PID~SUS_2021_PN JKT~TIM.json
#
#                                what_charged_articles
# 0  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...

# %%
unknown_charge = df_filtered[
    (df_filtered["what_charged_articles"].isna())
]

print(len(unknown_charge))
# Out:
# 44

# %%
unknown_charge.to_excel("unknown_charge.xlsx", index=False)

# %% [markdown]
# ## Unknown case number

# %%
data = pd.read_excel("rekap_data_terorisme_loc_v7.xlsx")
data.head()
# Out:
#                             File_Name                          case_id  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json    02/Pid. Sus./2014/PN. Jkt. Ut
# 1   1005_PID~SUS_2020_PN JKT~BRT.json  1005/Pid. Sus/2020/PN. Jkt. Brt
# 2   1006_PID~SUS_2020_PN JKT~BRT.json  1006/Pid. Sus/2020/PN. Jkt. Brt
# 3   1012_PID~SUS_2021_PN JKT~TIM.json  1012 Pid. SUS/2021/PN. Jkt. Tim
# 4   1014_PID~SUS_2021_PN JKT~TIM.json   1014/Pid. Sus/2021/PN Jkt. Tim
#
#                   what_case_number                        what_court_name  \
# 0    02/Pid. Sus./2014/PN. Jkt. Ut        Pengadilan Negeri Jakarta Utara
# 1  1005/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 2  1006/Pid. Sus/2020/PN. Jkt. Brt        Pengadilan Negeri Jakarta Barat
# 3  1012 Pid. SUS/2021/PN. Jkt. Tim  Pengadilan Negeri Jakarta Timur sejak
# 4   1014/Pid. Sus/2021/PN Jkt. Tim        Pengadilan Negeri Jakarta Timur
#
#   what_court_level                              what_charged_articles  \
# 0          pertama  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1          pertama  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2          pertama  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#   what_indictment_model                                what_proven_offense  \
# 0            Alternatif  permufakataan jahat dengan sengaja melakukan k...
# 1            Alternatif                            Tindak Pidana Terorisme
# 2            Alternatif                            Tindak Pidana Terorisme
# 3                   NaN                            Tindak Pidana Terorisme
# 4             Kombinasi    tindak pidana Terorisme dan Pendanaan Terorisme
#
#   what_verdict_per_charge what_appellate_outcome  ...  \
# 0                Terbukti                    NaN  ...
# 1                Terbukti                    NaN  ...
# 2                Terbukti                    NaN  ...
# 3                Terbukti                    NaN  ...
# 4       Primair: Terbukti                    NaN  ...
#
#                           why_radicalization_sources  \
# 0                                                NaN
# 1  kajian ustadz MUHLIS\n---\nFacebook\n---\ntele...
# 2  grup Media Sosial Whats App MENITI TAUHID\n---...
# 3  kajian Diniyah di Mushola daerah Ds. Pondok Su...
# 4                                                NaN
#
#                               why_motivation_factors  how_much_prison_term  \
# 0                                                NaN                   NaN
# 1                                                NaN  Years: 3 | Months: 6
# 2                                                NaN  Years: 3 | Months: 6
# 3  keinginan untuk hidup dibawah naungan Negara S...  Years: 3 | Months: 6
# 4                                                NaN  Years: 4 | Months: 6
#
#   how_much_injury_severity what_detention_credit  \
# 0                      NaN                   NaN
# 1         Tidak ada korban                   NaN
# 2         Tidak ada korban                  True
# 3         Tidak ada korban                   NaN
# 4         Tidak ada korban                  True
#
#        where_detention_location how_much_monetary_penalties  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3  Rumah Tahanan Negara (RUTAN)                         NaN
# 4                           NaN                  50.000.000
#
#   what_is_imputed_articles how_much_seized_money_amount when_indictment_date
# 0                      NaN                          NaN                  NaN
# 1                      NaN                          NaN                  NaN
# 2                      NaN                          NaN                  NaN
# 3                      NaN                          NaN                  NaN
# 4                      NaN                          NaN                  NaN
#
# [5 rows x 60 columns]

# %%
df_filtered = data[["File_Name", "case_id", "what_case_number"]]
df_filtered
# Out:
#                                              File_Name  \
# 0                   02_PID~ SUS~_2014_PN~JKT~ UT~.json
# 1                    1005_PID~SUS_2020_PN JKT~BRT.json
# 2                    1006_PID~SUS_2020_PN JKT~BRT.json
# 3                    1012_PID~SUS_2021_PN JKT~TIM.json
# 4                    1014_PID~SUS_2021_PN JKT~TIM.json
# ..                                                 ...
# 510  putusan_303_pid.sus_2019_pn_jkt.utr_2025122100...
# 511  putusan_373_pid.sus.teroris_2015_pn.jkt.utr._2...
# 512  putusan_459_pid.sus_2019_pn_jkt.utr_2026012014...
# 513  putusan_461_pid.sus_2019_pn_jkt.utr_2026012014...
# 514  putusan_620_pid.sus_2018_pn_.jkt_utr_202601201...
#
#                                      case_id  \
# 0              02/Pid. Sus./2014/PN. Jkt. Ut
# 1            1005/Pid. Sus/2020/PN. Jkt. Brt
# 2            1006/Pid. Sus/2020/PN. Jkt. Brt
# 3            1012 Pid. SUS/2021/PN. Jkt. Tim
# 4             1014/Pid. Sus/2021/PN Jkt. Tim
# ..                                       ...
# 510   303/Pid. Sus. Teroris/2019/PN Jkt. Utr
# 511  373/Pid. Sus. Teroris/2015/PN. Jkt. Utr
# 512   459/Pid. Sus. Teroris/2019/PN Jkt. Utr
# 513   461/Pid. Sus-Teroris/2019/PN. Jkt. Utr
# 514            620/Pid. Sus/2018/PN. Jkt Utr
#
#                             what_case_number
# 0              02/Pid. Sus./2014/PN. Jkt. Ut
# 1            1005/Pid. Sus/2020/PN. Jkt. Brt
# 2            1006/Pid. Sus/2020/PN. Jkt. Brt
# 3            1012 Pid. SUS/2021/PN. Jkt. Tim
# 4             1014/Pid. Sus/2021/PN Jkt. Tim
# ..                                       ...
# 510   303/Pid. Sus. Teroris/2019/PN Jkt. Utr
# 511  373/Pid. Sus. Teroris/2015/PN. Jkt. Utr
# 512   459/Pid. Sus. Teroris/2019/PN Jkt. Utr
# 513   461/Pid. Sus-Teroris/2019/PN. Jkt. Utr
# 514            620/Pid. Sus/2018/PN. Jkt Utr
#
# [515 rows x 3 columns]

# %%
df_filtered.to_excel("check_case_number_2.xlsx")

# %% [markdown]
# ### Court Location and District Court (Unknown)

# %%
data = pd.read_excel("rekap_data_terorisme_loc_v8.xlsx")
data.head()
# Out:
#                             File_Name                       case_id  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json    02/Pid.Sus./2014/PN.Jkt.Ut
# 1   1005_PID~SUS_2020_PN JKT~BRT.json  1005/Pid.Sus/2020/PN.Jkt.Brt
# 2   1006_PID~SUS_2020_PN JKT~BRT.json  1006/Pid.Sus/2020/PN.Jkt.Brt
# 3   1012_PID~SUS_2021_PN JKT~TIM.json   1012Pid.SUS/2021/PN.Jkt.Tim
# 4   1014_PID~SUS_2021_PN JKT~TIM.json   1014/Pid.Sus/2021/PNJkt.Tim
#
#                what_case_number                  what_court_name  \
# 0    02/Pid.Sus./2014/PN.Jkt.Ut  Pengadilan Negeri Jakarta Utara
# 1  1005/Pid.Sus/2020/PN.Jkt.Brt  Pengadilan Negeri Jakarta Barat
# 2  1006/Pid.Sus/2020/PN.Jkt.Brt  Pengadilan Negeri Jakarta Barat
# 3   1012Pid.SUS/2021/PN.Jkt.Tim  Pengadilan Negeri Jakarta Timur
# 4   1014/Pid.Sus/2021/PNJkt.Tim  Pengadilan Negeri Jakarta Timur
#
#   what_court_level                              what_charged_articles  \
# 0          pertama  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1          pertama  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2          pertama  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4          pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#   what_indictment_model                                what_proven_offense  \
# 0            Alternatif  permufakataan jahat dengan sengaja melakukan k...
# 1            Alternatif                            Tindak Pidana Terorisme
# 2            Alternatif                            Tindak Pidana Terorisme
# 3                   NaN                            Tindak Pidana Terorisme
# 4             Kombinasi    tindak pidana Terorisme dan Pendanaan Terorisme
#
#   what_verdict_per_charge what_appellate_outcome  ...  \
# 0                Terbukti                    NaN  ...
# 1                Terbukti                    NaN  ...
# 2                Terbukti                    NaN  ...
# 3                Terbukti                    NaN  ...
# 4       Primair: Terbukti                    NaN  ...
#
#                           why_radicalization_sources  \
# 0                                                NaN
# 1  kajian ustadz MUHLIS\n---\nFacebook\n---\ntele...
# 2  grup Media Sosial Whats App MENITI TAUHID\n---...
# 3  kajian Diniyah di Mushola daerah Ds. Pondok Su...
# 4                                                NaN
#
#                               why_motivation_factors  how_much_prison_term  \
# 0                                                NaN                   NaN
# 1                                                NaN  Years: 3 | Months: 6
# 2                                                NaN  Years: 3 | Months: 6
# 3  keinginan untuk hidup dibawah naungan Negara S...  Years: 3 | Months: 6
# 4                                                NaN  Years: 4 | Months: 6
#
#   how_much_injury_severity what_detention_credit  \
# 0                      NaN                   NaN
# 1         Tidak ada korban                   NaN
# 2         Tidak ada korban                  True
# 3         Tidak ada korban                   NaN
# 4         Tidak ada korban                  True
#
#        where_detention_location how_much_monetary_penalties  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3  Rumah Tahanan Negara (RUTAN)                         NaN
# 4                           NaN                  50.000.000
#
#   what_is_imputed_articles how_much_seized_money_amount when_indictment_date
# 0                      NaN                          NaN                  NaN
# 1                      NaN                          NaN                  NaN
# 2                      NaN                          NaN                  NaN
# 3                      NaN                          NaN                  NaN
# 4                      NaN                          NaN                  NaN
#
# [5 rows x 79 columns]

# %%
data.columns
# Out:
# Index(['File_Name', 'case_id', 'what_case_number', 'what_court_name',
#        'what_court_level', 'what_charged_articles', 'what_indictment_model',
#        'what_proven_offense', 'what_verdict_per_charge',
#        'what_appellate_outcome', 'what_evidence_items',
#        'what_evidence_disposition', 'what_defense_plea',
#        'what_pelatihan_activities', 'what_perencanaan_activities',
#        'what_tindakan_activities', 'what_normalized_articles',
#        'when_appeal_timeline', 'when_arrest_date', 'when_crime_time_range',
#        'when_detention_timeline', 'when_district_court_date',
#        'when_tahun_putusan', 'when_bulan_putusan', 'when_tahun_penangkapan',
#        'when_lag_bulan', 'where_district_court', 'where_court_location',
#        'where_normalized_court_province', 'where_normalized_court_city',
#        'where_normalized_court_code', 'who_defendants', 'who_co_defendants',
#        'who_defense_counsels', 'who_investigators', 'who_judges', 'who_clerk',
#        'who_prosecutors', 'who_witnesses',
#        'who_defendant_ideology_affiliation', 'who_provinsi_jaringan',
#        'who_kota_jaringan', 'who_normalized_defense_counsels',
#        'who_normalized_judges', 'who_normalized_clerk',
#        'who_normalized_prosecutors', 'who_normalized_co_defendants',
#        'why_reasoning_evidence', 'why_reasoning_appeal',
#        'why_classified_radicalization_sources', 'why_radicalization_channel',
#        'why_classified_motivation_factors',
#        'why_classified_aggravating_factors', 'how_many_witness_count',
#        'how_many_charge_count', 'how_many_defendant_count',
#        'how_many_evidence_item_count', 'what_has_attack_plan',
#        'what_attack_preparation_activities', 'what_attack_plan_summary',
#        'what_defendant_chat_platform',
#        'when_defendant_local_network_joined_at', 'where_activity_locations',
#        'where_crime_location', 'where_arrest_location',
#        'who_defendant_local_network', 'who_related_entities',
#        'why_aggravating_factors', 'why_mitigating_factors',
#        'why_radicalization_sources', 'why_motivation_factors',
#        'how_much_prison_term', 'how_much_injury_severity',
#        'what_detention_credit', 'where_detention_location',
#        'how_much_monetary_penalties', 'what_is_imputed_articles',
#        'how_much_seized_money_amount', 'when_indictment_date'],
#       dtype='str')

# %%
df_court = data[["File_Name", "what_court_name", "where_court_location", "where_district_court"]]
df_court
# Out:
#                                              File_Name  \
# 0                   02_PID~ SUS~_2014_PN~JKT~ UT~.json
# 1                    1005_PID~SUS_2020_PN JKT~BRT.json
# 2                    1006_PID~SUS_2020_PN JKT~BRT.json
# 3                    1012_PID~SUS_2021_PN JKT~TIM.json
# 4                    1014_PID~SUS_2021_PN JKT~TIM.json
# ..                                                 ...
# 510  putusan_303_pid.sus_2019_pn_jkt.utr_2025122100...
# 511  putusan_373_pid.sus.teroris_2015_pn.jkt.utr._2...
# 512  putusan_459_pid.sus_2019_pn_jkt.utr_2026012014...
# 513  putusan_461_pid.sus_2019_pn_jkt.utr_2026012014...
# 514  putusan_620_pid.sus_2018_pn_.jkt_utr_202601201...
#
#                      what_court_name where_court_location  \
# 0    Pengadilan Negeri Jakarta Utara        Jakarta Utara
# 1    Pengadilan Negeri Jakarta Barat        Jakarta Barat
# 2    Pengadilan Negeri Jakarta Barat        Jakarta Barat
# 3    Pengadilan Negeri Jakarta Timur        Jakarta Timur
# 4    Pengadilan Negeri Jakarta Timur        Jakarta Timur
# ..                               ...                  ...
# 510  Pengadilan Negeri Jakarta Utara        Jakarta Utara
# 511  Pengadilan Negeri Jakarta Utara        Jakarta Utara
# 512  Pengadilan Negeri Jakarta Utara        Jakarta Utara
# 513  Pengadilan Negeri Jakarta Utara        Jakarta Utara
# 514  Pengadilan Negeri Jakarta Utara        Jakarta Utara
#
#                 where_district_court
# 0    Pengadilan Negeri Jakarta Utara
# 1    Pengadilan Negeri Jakarta Barat
# 2    Pengadilan Negeri Jakarta Barat
# 3    Pengadilan Negeri Jakarta Timur
# 4    Pengadilan Negeri Jakarta Timur
# ..                               ...
# 510  Pengadilan Negeri Jakarta Utara
# 511  Pengadilan Negeri Jakarta Utara
# 512  Pengadilan Negeri Jakarta Utara
# 513  Pengadilan Negeri Jakarta Utara
# 514  Pengadilan Negeri Jakarta Utara
#
# [515 rows x 4 columns]

# %%
df_court.to_excel("check_court_location_district_2.xlsx")

# %% [markdown]
# ## Cases Normalization

# %%
data = pd.read_excel("rekap_data_terorisme_loc_v8.xlsx")
data.head()
# Out:
#                             File_Name                       case_id  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json    02/Pid.Sus./2014/PN.Jkt.Ut
# 1   1005_PID~SUS_2020_PN JKT~BRT.json  1005/Pid.Sus/2020/PN.Jkt.Brt
# 2   1006_PID~SUS_2020_PN JKT~BRT.json  1006/Pid.Sus/2020/PN.Jkt.Brt
# 3   1012_PID~SUS_2021_PN JKT~TIM.json   1012Pid.SUS/2021/PN.Jkt.Tim
# 4   1014_PID~SUS_2021_PN JKT~TIM.json   1014/Pid.Sus/2021/PNJkt.Tim
#
#                what_case_number                  what_court_name  \
# 0    02/Pid.Sus./2014/PN.Jkt.Ut  Pengadilan Negeri Jakarta Utara
# 1  1005/Pid.Sus/2020/PN.Jkt.Brt  Pengadilan Negeri Jakarta Barat
# 2  1006/Pid.Sus/2020/PN.Jkt.Brt  Pengadilan Negeri Jakarta Barat
# 3   1012Pid.SUS/2021/PN.Jkt.Tim  Pengadilan Negeri Jakarta Timur
# 4   1014/Pid.Sus/2021/PNJkt.Tim  Pengadilan Negeri Jakarta Timur
#
#   what_court_level                              what_charged_articles  \
# 0  tingkat pertama  Pasal 15 Jo. Pasal 6 Perpu No. 1 Tahun 2002\n-...
# 1  tingkat pertama  Pasal 15 Jo Pasal 7 Undang-Undang Republik Ind...
# 2  tingkat pertama  Pasal 15 jo Pasal 7 Undang-Undang Republik Ind...
# 3  tingkat pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
# 4  tingkat pertama  Pasal 15 jo. Pasal 7 Peraturan Pemerintah Peng...
#
#   what_indictment_model                                what_proven_offense  \
# 0            alternatif  permufakataan jahat dengan sengaja melakukan k...
# 1            alternatif                            Tindak Pidana Terorisme
# 2            alternatif                            Tindak Pidana Terorisme
# 3       tidak diketahui                            Tindak Pidana Terorisme
# 4             kombinasi    tindak pidana Terorisme dan Pendanaan Terorisme
#
#   what_verdict_per_charge what_appellate_outcome  ...  \
# 0               convicted                    NaN  ...
# 1               convicted                    NaN  ...
# 2               convicted                    NaN  ...
# 3               convicted                    NaN  ...
# 4               convicted                    NaN  ...
#
#                               why_mitigating_factors  \
# 0                                                NaN
# 1  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
# 2  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
# 3  Terdakwa bersikap sopan dipersidangan\n---\nTe...
# 4  Terdakwa belum pernah dihukum\n---\nTerdakwa m...
#
#                           why_radicalization_sources  \
# 0                                                NaN
# 1  kajian ustadz MUHLIS\n---\nFacebook\n---\ntele...
# 2  grup Media Sosial Whats App MENITI TAUHID\n---...
# 3  kajian Diniyah di Mushola daerah Ds. Pondok Su...
# 4                                                NaN
#
#                               why_motivation_factors  how_much_prison_term  \
# 0                                                NaN                   NaN
# 1                                                NaN  Years: 3 | Months: 6
# 2                                                NaN  Years: 3 | Months: 6
# 3  keinginan untuk hidup dibawah naungan Negara S...  Years: 3 | Months: 6
# 4                                                NaN  Years: 4 | Months: 6
#
#   how_much_injury_severity      where_detention_location  \
# 0                      NaN                           NaN
# 1         Tidak ada korban                           NaN
# 2         Tidak ada korban                           NaN
# 3         Tidak ada korban  Rumah Tahanan Negara (RUTAN)
# 4         Tidak ada korban                           NaN
#
#   how_much_monetary_penalties  what_is_imputed_articles  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                  50.000.000                       NaN
#
#   how_much_seized_money_amount when_indictment_date
# 0                          NaN                  NaN
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
# [5 rows x 81 columns]

# %%
data.columns
# Out:
# Index(['File_Name', 'case_id', 'what_case_number', 'what_court_name',
#        'what_court_level', 'what_charged_articles', 'what_indictment_model',
#        'what_proven_offense', 'what_verdict_per_charge',
#        'what_appellate_outcome', 'what_evidence_items',
#        'what_evidence_disposition', 'what_defense_plea',
#        'what_pelatihan_activities', 'what_perencanaan_activities',
#        'what_tindakan_activities', 'what_normalized_articles',
#        'what_detention_credit', 'what_attack_plan_summary',
#        'when_appeal_timeline', 'when_arrest_date', 'when_crime_time_range',
#        'when_detention_timeline', 'when_district_court_date',
#        'when_tahun_putusan', 'when_bulan_putusan', 'when_tahun_penangkapan',
#        'when_lag_bulan', 'where_district_court', 'where_court_location',
#        'where_normalized_court_province', 'where_normalized_court_city',
#        'where_normalized_court_code', 'who_defendants', 'who_co_defendants',
#        'who_defense_counsels', 'who_investigators', 'who_judges', 'who_clerk',
#        'who_prosecutors', 'who_witnesses',
#        'who_defendant_ideology_affiliation', 'who_provinsi_jaringan',
#        'who_kota_jaringan', 'who_normalized_defense_counsels',
#        'who_normalized_judges', 'who_normalized_clerk',
#        'who_normalized_prosecutors', 'who_normalized_co_defendants',
#        'why_reasoning_evidence', 'why_reasoning_appeal',
#        'why_classified_radicalization_sources', 'why_radicalization_channel',
#        'why_classified_motivation_factors',
#        'why_classified_aggravating_factors', 'how_much_prison_term_years',
#        'how_much_prison_term_months', 'how_many_witness_count',
#        'how_many_charge_count', 'how_many_defendant_count',
#        'how_many_evidence_item_count', 'what_has_attack_plan',
#        'what_attack_preparation_activities', 'what_defendant_chat_platform',
#        'when_defendant_local_network_joined_at', 'where_activity_locations',
#        'where_crime_location', 'where_arrest_location',
#        'who_defendant_local_network', 'who_related_entities',
#        'why_aggravating_factors', 'why_mitigating_factors',
#        'why_radicalization_sources', 'why_motivation_factors',
#        'how_much_prison_term', 'how_much_injury_severity',
#        'where_detention_location', 'how_much_monetary_penalties',
#        'what_is_imputed_articles', 'how_much_seized_money_amount',
#        'when_indictment_date'],
#       dtype='str')

# %%
# filtered_data = data[["File_Name", "what_case_number", "what_court_level", "what_indictment_model", "what_verdict_per_charge", "how_much_prison_term", "what_detention_credit", "when_indictment_date", 
#                       "when_arrest_date", "when_detention_timeline", "when_appeal_timeline", "why_aggravating_factors", "why_mitigating_factors", "what_has_attack_plan", "what_attack_plan_summary",
#                       "why_motivation_factors"]]

filtered_data = data[["File_Name", "what_case_number", "when_arrest_date", "when_appeal_timeline", "when_district_court_date", "what_has_attack_plan", "what_attack_plan_summary"]]

# %%
filtered_data.head()
# Out:
#                             File_Name              what_case_number  \
# 0  02_PID~ SUS~_2014_PN~JKT~ UT~.json    02/Pid.Sus./2014/PN.Jkt.Ut
# 1   1005_PID~SUS_2020_PN JKT~BRT.json  1005/Pid.Sus/2020/PN.Jkt.Brt
# 2   1006_PID~SUS_2020_PN JKT~BRT.json  1006/Pid.Sus/2020/PN.Jkt.Brt
# 3   1012_PID~SUS_2021_PN JKT~TIM.json   1012Pid.SUS/2021/PN.Jkt.Tim
# 4   1014_PID~SUS_2021_PN JKT~TIM.json   1014/Pid.Sus/2021/PNJkt.Tim
#
#   when_arrest_date when_appeal_timeline when_district_court_date  \
# 0       2013-08-28      tidak diketahui                      NaN
# 1       2019-11-04      tidak diketahui               2020-09-14
# 2       2019-10-26      tidak diketahui               2020-10-12
# 3       2021-04-10      tidak diketahui               2022-03-30
# 4       2021-04-12      tidak diketahui               2022-03-07
#
#   what_has_attack_plan                           what_attack_plan_summary
# 0                  NaN                                    tidak diketahui
# 1                False                                    tidak diketahui
# 2                 True  Penyerangan terhadap Kantor Polisi di Pare Ked...
# 3                False                                    tidak diketahui
# 4                False                                    tidak diketahui

# %%
filtered_data.to_excel("cases_analysis_3.xlsx")

# %%
indictment_date = filtered_data[
    (filtered_data["when_appeal_timeline"].isna())
]

print(len(indictment_date))
# Out:
# 0
